# %%
import pandas as pd
import seaborn as sns
import numpy as np
from scipy.stats.stats import pearsonr,spearmanr
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, Imputer, MinMaxScaler, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split, KFold
from statsmodels.api import Logit
import xgboost as xgb
# from imblearn.over_sampling import SMOTE
import random

import holidays
import requests
from time import sleep
from shutil import copyfile
from scipy import stats
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
pd.options.display.max_columns = 999
pd.options.display.max_rows = 999

# %%
# # To find out where the pyspark
# import findspark
# findspark.init()

# # Creating Spark Context
# from pyspark import SparkContext, SQLContext
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.functions import UserDefinedFunction as udf
from pyspark.sql.types import StringType, IntegerType, DecimalType, DoubleType

# %%
from pyspark.ml.feature import VectorAssembler,CountVectorizer
from pyspark.ml.regression import LinearRegression
from pyspark.ml.evaluation import RegressionEvaluator

# %%
"""SimpleApp.py"""
spark = SparkSession.builder.appName("FirstSparkApp").getOrCreate()

# %%
df_spark = spark.read\
    .format("com.databricks.spark.csv")\
    .option("header", "true") \
    .option("mode", "DROPMALFORMED")\
    .option("inferSchema", "true")\
    .load('/home/arditto_trianggada3/Workspace/ds-ovo-test/dataset/trip_merge_4_fe_all.csv')

# %%
df1 = df_spark.limit(10).toPandas()

# %%
df1.head(5)
# Out:
#                           medallion                      hack_license  \
# 0  91F6EB84975BBC867E32CB113C7C2CD5  AD8751110E6292079EB10EB9481FE1A6
# 1  C1B9DA774DC2BBC6DE27CE994E7F44A0  E1B595FD55E4C82C1E213EB17438107A
# 2  9BA84250355AB3FC031C9252D395BF8A  16BB0D96A0DCC853AEC7F55C8D6C71E0
# 3  205A696DF62AD03C88DA8C5EC5248639  579C41EA5EC846F8B641A42F9EE3E855
# 4  EE75E5927D00739AC342810C336A825E  1B4E92431F9DA4D49874EC76E769E874
#
#   vendor_id  rate_code store_and_fwd_flag     pickup_datetime  \
# 0       CMT          1                  N 2013-04-04 18:47:45
# 1       CMT          1                  N 2013-04-04 17:59:50
# 2       CMT          1                  N 2013-04-04 18:12:01
# 3       CMT          1                  N 2013-04-04 20:12:57
# 4       CMT          1                  N 2013-04-05 02:48:11
#
#      dropoff_datetime  passenger_count  trip_time_in_secs  trip_distance  \
# 0 2013-04-04 19:00:25                1                759            2.5
# 1 2013-04-04 18:21:48                1               1318            3.6
# 2 2013-04-04 18:25:24                1                799            1.9
# 3 2013-04-04 20:29:55                1               1017            3.6
# 4 2013-04-05 02:51:21                2                189            0.7
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.957855        40.765320         -73.976273         40.785648
# 1        -73.982880        40.754990         -74.009186         40.715374
# 2        -73.978119        40.763451         -73.955666         40.776642
# 3        -74.006371        40.744755         -73.961662         40.761082
# 4        -73.985191        40.754932         -73.990776         40.747997
#
#   payment_type  fare_amount  surcharge  mta_tax  tip_amount  tolls_amount  \
# 0          CRD         11.0        1.0      0.5        2.50           0.0
# 1          CRD         16.5        1.0      0.5        3.60           0.0
# 2          CRD         10.0        1.0      0.5        3.45           0.0
# 3          CRD         15.0        0.5      0.5        3.20           0.0
# 4          CRD          4.5        0.5      0.5        1.10           0.0
#
#    total_amount  pickup_longitude_bin  pickup_latitude_bin  \
# 0         15.00               -73.955               40.770
# 1         21.60               -73.980               40.755
# 2         14.95               -73.975               40.765
# 3         19.20               -74.005               40.745
# 4          6.60               -73.985               40.755
#
#    dropoff_longitude_bin  dropoff_latitude_bin  pickup_addr_zipcode  \
# 0                -73.975                40.790              10065.0
# 1                -74.005                40.720              10036.0
# 2                -73.955                40.780              10019.0
# 3                -73.960                40.765              10011.0
# 4                -73.990                40.750              10036.0
#
#   pickup_addr_place pickup_addr_neighborhood pickup_addr_sublocal  \
# 0         E 67th St                     None            Manhattan
# 1     Verizon Plaza                     None            Manhattan
# 2           7th Ave                     None            Manhattan
# 3         W 19th St                     None            Manhattan
# 4     Verizon Plaza                     None            Manhattan
#
#   pickup_addr_local pickup_addr_administrative_area_level_2  \
# 0          New York                         New York County
# 1          New York                         New York County
# 2          New York                         New York County
# 3          New York                         New York County
# 4          New York                         New York County
#
#    dropoff_addr_zipcode dropoff_addr_place dropoff_addr_neighborhood  \
# 0               10024.0          W 83rd St                      None
# 1               10007.0          Warren St                      None
# 2               10028.0          E 81st St                      None
# 3               10022.0          E 60th St                      None
# 4               10120.0   West 33rd Street                      None
#
#   dropoff_addr_sublocal dropoff_addr_local  \
# 0             Manhattan           New York
# 1             Manhattan           New York
# 2             Manhattan           New York
# 3             Manhattan           New York
# 4             Manhattan           New York
#
#   dropoff_addr_administrative_area_level_2 pickup_to_dropoff_zipcode  \
# 0                          New York County           10065.0_10024.0
# 1                          New York County           10036.0_10007.0
# 2                          New York County           10019.0_10028.0
# 3                          New York County           10011.0_10022.0
# 4                          New York County           10036.0_10120.0
#
#           pickup_to_dropoff_place pickup_to_dropoff_neighborhood  \
# 0             E 67th St_W 83rd St                        nan_nan
# 1         Verizon Plaza_Warren St                        nan_nan
# 2               7th Ave_E 81st St                        nan_nan
# 3             W 19th St_E 60th St                        nan_nan
# 4  Verizon Plaza_West 33rd Street                        nan_nan
#
#   pickup_to_dropoff_sublocal pickup_to_dropoff_local  \
# 0        Manhattan_Manhattan       New York_New York
# 1        Manhattan_Manhattan       New York_New York
# 2        Manhattan_Manhattan       New York_New York
# 3        Manhattan_Manhattan       New York_New York
# 4        Manhattan_Manhattan       New York_New York
#
#   pickup_to_dropoff_administrative_area_level_2  pickup_month  \
# 0               New York County_New York County             4
# 1               New York County_New York County             4
# 2               New York County_New York County             4
# 3               New York County_New York County             4
# 4               New York County_New York County             4
#
#   pickup_dayofweek  pickup_hour  dropoff_month dropoff_dayofweek  \
# 0         Thursday           18              4          Thursday
# 1         Thursday           17              4          Thursday
# 2         Thursday           18              4          Thursday
# 3         Thursday           20              4          Thursday
# 4           Friday            2              4            Friday
#
#    dropoff_hour  is_public_holiday  is_weekend  is_holiday  trip_night  \
# 0            19                  0           0           0           1
# 1            18                  0           0           0           1
# 2            18                  0           0           0           1
# 3            20                  0           0           0           1
# 4             2                  0           0           0           0
#
#    trip_late_night  trip_dist_euclidean  trip_dist_manhattan
# 0                0             0.027431             0.038746
# 1                0             0.047555             0.065922
# 2                0             0.026041             0.035644
# 3                1             0.047597             0.061036
# 4                1             0.008904             0.012520

# %%
class labelEnc():
    """
    Label Encoding
    """
    def __init__(self, categorical_features):
        self.key = categorical_features
        self.enc = [LabelEncoder() for c in categorical_features]
      
    def fit(self,X, y=None):
        y = np.array(X)
        self.categorical_feat_classes = {}
        for i in range(len(self.key)):
            c = self.key[i]
            self.enc[i] = self.enc[i].fit(y[:,c])
            self.categorical_feat_classes[c] = self.enc[i].classes_
        return self
      
    def transform(self,X):
        y = np.array(X)
        for i in range(len(self.key)):
            c = self.key[i]
            y[:,c] = self.enc[i].transform(y[:,c])
        return y
      
    def fit_transform(self,X, y=None):
        self.fit(X,y)
        y = np.array(X)
        for i in range(len(self.key)):
            c = self.key[i]
            y[:,c] = self.enc[i].transform(y[:,c])
        return y
    
class oneHotEnc():
    """
    One Hot Encoding
    """
    def __init__(self, categorical_features, fit_onehot):
        self.key = categorical_features
        self.enc = fit_onehot.set_params(categorical_features=categorical_features)

    def fit(self, X, y=None):
        if len(self.key)>0:
            #global categorical_onehot_idx,categorical_onehot_nval 
            self.enc = self.enc.fit(X,y)
            categorical_onehot_idx = self.enc.feature_indices_
            categorical_onehot_nval = self.enc.n_values_
            self.categorical_onehot_idx = categorical_onehot_idx
            self.categorical_onehot_nval = categorical_onehot_nval
        return self

    def transform(self, X):
        if len(self.key)>0:
            y = self.enc.transform(X)
            y = y if type(y)==np.ndarray else y.toarray()
        else:
            y=X
        return y
      
    def fit_transform(self,X, y=None):
        if len(self.key)>0:
            y = self.fit(X,y).transform(X)
            y = y if type(y)==np.ndarray else y.toarray()
        return y

def getColnames(le,onehotenc,df):
    if len(onehotenc.key)>0:
        categorical_onehot_idx = onehotenc.enc.feature_indices_
        categorical_onehot_nval = onehotenc.enc.n_values_
        colname = []
        k=0
        for i in categorical_onehot_idx[:-1]:
            feat = list_col_cat[k]
            for j in range(categorical_onehot_nval[k]):
                val = le.categorical_feat_classes[le.key[k]][j]
                colname.append("{}_{}".format(feat,val))
            k+=1
        lcol_num = [x for x in df.dtypes.index.values if not(x in list_col_cat)]
        for i in lcol_num:
            colname.append("{}".format(i))
    else:
        colname = df.columns.values
    return colname

# %%
## Save model
class bst_models():
  
  def __init__(self,colname, score_method="mean"):
    self.model = []
    self.colname = colname
    self.score_method = score_method
  
  def add_model(self, model):
    self.model.append(model)
    return self
  
  def predict(self,X):
    d = xgb.DMatrix(X,feature_names=self.colname)
    preds=[]
    for m in self.model:
      pred = m.predict(d)
      preds.append(list(pred))
      
    K = len(preds)
    nrow = len(preds[0])
    self.K = K
    self.nrow = nrow
    pred = []
    for i in range(nrow):
      sum1=0
      for j in range(K):
        if self.score_method == "max":
          sum1 = max(sum1, preds[j][i])
        else:
          sum1+=preds[j][i]
      if self.score_method == "max":
        pred.append(sum1)
      else:
        pred.append(sum1/K)
      
    return pd.Series(pred)
  
  def get_importances(self):
    imp = dict()
    cols = self.model[0].feature_names
    for col in cols:
      imp1=0
      k1 = 0
      for j in range(self.K):
        try:
          imp1+=self.model[j].get_score()[col]
        except (KeyError):
          pass
        k1 += 1
      imp[col] = imp1 / k1
    imp = pd.Series(imp).sort_values(ascending=False)
    return imp

# %%
# df = df_spark.limit(1000000).toPandas()

# %%
df_orig = pd.read_csv("./dataset/trip_merge_4_fe_all.csv")
# Out:
# /home/arditto_trianggada3/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
Nall = df_orig.shape[0]
Nsample = 1000000

isample = random.sample(range(Nall),Nsample)
df = df_orig.loc[isample,:].reset_index(drop=True)

# %%
list_col_excl = [
    'medallion',
    'hack_license',
    'vendor_id',
    'pickup_addr_neighborhood',
    'dropoff_addr_neighborhood',
    'store_and_fwd_flag',
    'dropoff_addr_local','pickup_addr_local',
    'mta_tax','payment_type','fare_amount','surcharge','tolls_amount','total_amount',
    'pickup_longitude_bin','dropoff_longitude_bin',
    'pickup_longitude','dropoff_longitude',
    'pickup_latitude_bin','dropoff_latitude_bin',
    'pickup_latitude','dropoff_latitude',
    'dropoff_datetime','pickup_datetime',
    'is_weekend','is_public_holiday',
    'dropoff_month','pickup_month'
]

df = df.drop(list_col_excl,axis=1)

# %%
## Menghitung Nilai Null
df_cnt = df.count()
df_cnt = df_cnt.map(lambda x: 1.0-(x*1.0/df.shape[0]))
df_cnt.sort_values(ascending=False,inplace=True)
df_cnt
# Out:
# dropoff_addr_sublocal                            0.007207
# pickup_addr_place                                0.005737
# dropoff_addr_administrative_area_level_2         0.005622
# dropoff_addr_place                               0.005609
# pickup_addr_administrative_area_level_2          0.004156
# pickup_addr_sublocal                             0.003545
# dropoff_addr_zipcode                             0.000042
# pickup_addr_zipcode                              0.000040
# trip_dist_manhattan                              0.000000
# trip_dist_euclidean                              0.000000
# passenger_count                                  0.000000
# trip_time_in_secs                                0.000000
# trip_distance                                    0.000000
# tip_amount                                       0.000000
# pickup_to_dropoff_zipcode                        0.000000
# pickup_to_dropoff_place                          0.000000
# pickup_to_dropoff_neighborhood                   0.000000
# pickup_to_dropoff_sublocal                       0.000000
# pickup_to_dropoff_local                          0.000000
# pickup_to_dropoff_administrative_area_level_2    0.000000
# pickup_dayofweek                                 0.000000
# pickup_hour                                      0.000000
# dropoff_dayofweek                                0.000000
# dropoff_hour                                     0.000000
# is_holiday                                       0.000000
# trip_night                                       0.000000
# trip_late_night                                  0.000000
# rate_code                                        0.000000
# dtype: float64

# %%
## ---------------------------------------------------------------------
## Null imputation
## ---------------------------------------------------------------------
data = df.copy()

## Menghitung Nilai Null
df_cnt = data.count()
df_cnt = df_cnt.map(lambda x: 1.0-(x*1.0/df.shape[0]))
df_cnt.sort_values(ascending=False,inplace=True)

## Mengambil column dengan Null lebih dari 20% kecuali n tahun restruk
feat_null = df_cnt[df_cnt>=0.2].index.tolist()
feat_null = [x for x in feat_null if not(x in [
 'tip_amount'
])]

## Membuang Kolom data dengan Null lebih dari 20%
lcol = data.columns.values
lcol = [x for x in lcol if not(x in feat_null)]
data = data.loc[:,lcol].reset_index(drop=True)

## Cek kolom data
tmp = data.apply(lambda x: x.count(), axis=0)
tmp = [tmp.index[i] for i in range(len(tmp)) if tmp[i]<data.shape[0]]

## Kolom identitas
exc_col = []
exc_col = np.append(exc_col,[
 'tip_amount'
])

## Missing Values Handling selain kolom identitas
for col in data.columns.values:
    if not(col in exc_col):
#         print(col)
        ds = data[col]
        typ = ds.dtype
        ## Ganti dengan modus untuk object dan categorical
        if typ==object:
            ds = ds.fillna(ds.mode()[0])
        elif type(typ)==pd.core.dtypes.dtypes.CategoricalDtype:
            ds = ds.fillna(ds.mode()[0])
        ## Untuk numeric ganti dengan median
        else:
            ds = ds.fillna(ds.median())
        data[col] = ds
        

### Data minus jadi 0
#for col in data.columns.values[M:N+1]:
#  data[col] = data[col].map(lambda x: x if x>0 else 0)
#data = data.reset_index(drop=True)

# target_count = data['fare_amount_sum'].value_counts()
# print('Class 0:', target_count[0])
# print('Class 1:', target_count[1])
# print('Proportion:', round(target_count[0] / target_count[1], 2), ': 1')
# target_count.plot(kind='bar', title='Count (TARGET)');

sns.distplot(data['tip_amount'])

df = data.copy()

# %%
## Menghitung Nilai Null
df_cnt = df.count()
df_cnt = df_cnt.map(lambda x: 1.0-(x*1.0/df.shape[0]))
df_cnt.sort_values(ascending=False,inplace=True)
df_cnt
# Out:
# trip_dist_manhattan                              0.0
# trip_dist_euclidean                              0.0
# passenger_count                                  0.0
# trip_time_in_secs                                0.0
# trip_distance                                    0.0
# tip_amount                                       0.0
# pickup_addr_zipcode                              0.0
# pickup_addr_place                                0.0
# pickup_addr_sublocal                             0.0
# pickup_addr_administrative_area_level_2          0.0
# dropoff_addr_zipcode                             0.0
# dropoff_addr_place                               0.0
# dropoff_addr_sublocal                            0.0
# dropoff_addr_administrative_area_level_2         0.0
# pickup_to_dropoff_zipcode                        0.0
# pickup_to_dropoff_place                          0.0
# pickup_to_dropoff_neighborhood                   0.0
# pickup_to_dropoff_sublocal                       0.0
# pickup_to_dropoff_local                          0.0
# pickup_to_dropoff_administrative_area_level_2    0.0
# pickup_dayofweek                                 0.0
# pickup_hour                                      0.0
# dropoff_dayofweek                                0.0
# dropoff_hour                                     0.0
# is_holiday                                       0.0
# trip_night                                       0.0
# trip_late_night                                  0.0
# rate_code                                        0.0
# dtype: float64

# %%
df.dtypes
# Out:
# rate_code                                          int64
# passenger_count                                    int64
# trip_time_in_secs                                  int64
# trip_distance                                    float64
# tip_amount                                       float64
# pickup_addr_zipcode                              float64
# pickup_addr_place                                 object
# pickup_addr_sublocal                              object
# pickup_addr_administrative_area_level_2           object
# dropoff_addr_zipcode                             float64
# dropoff_addr_place                                object
# dropoff_addr_sublocal                             object
# dropoff_addr_administrative_area_level_2          object
# pickup_to_dropoff_zipcode                         object
# pickup_to_dropoff_place                           object
# pickup_to_dropoff_neighborhood                    object
# pickup_to_dropoff_sublocal                        object
# pickup_to_dropoff_local                           object
# pickup_to_dropoff_administrative_area_level_2     object
# pickup_dayofweek                                  object
# pickup_hour                                        int64
# dropoff_dayofweek                                 object
# dropoff_hour                                       int64
# is_holiday                                         int64
# trip_night                                         int64
# trip_late_night                                    int64
# trip_dist_euclidean                              float64
# trip_dist_manhattan                              float64
# dtype: object

# %%
# df['pickup_to_dropoff_local_set'] = df['pickup_to_dropoff_local_set'].map(lambda x: ','.join(np.sort(x.replace('[','').replace(']','').replace(', ',',').split(',')).tolist()))

# %%
list_col_excl1 = [
 'pickup_to_dropoff_zipcode',
 'pickup_to_dropoff_place',
 'pickup_to_dropoff_neighborhood',
 'pickup_to_dropoff_sublocal',
 'pickup_to_dropoff_local',
 'pickup_to_dropoff_administrative_area_level_2',
 'pickup_addr_place',
 'dropoff_addr_place'
]

list_col_excl1 = [x for x in list_col_excl1 if not(x in list_col_excl)]

# %%
target_var = 'tip_amount'
dtype = df.dtypes.drop(list_col_excl1+[target_var])
list_col = dtype.index.values.tolist()

X = df.loc[:, list_col]
Y = df[target_var]

# %%
list_col_cat = [x for x in X.columns.values if ((X[x].dtypes==object) or (type(X[x].dtypes)==pd.core.dtypes.dtypes.CategoricalDtype))]
list_idx_cat = [i for i in range(len(X.columns.values)) if X.columns.values[i] in list_col_cat]

# Label Encoding
le = labelEnc(categorical_features=list_idx_cat)
le.fit(X)
categorical_feat_classes = le.categorical_feat_classes

### One Hot Encoding
onehotenc = oneHotEnc(categorical_features=list_idx_cat, fit_onehot=OneHotEncoder())

### Feature scaling
scaler = StandardScaler()

### Merge preprocess pipeline
X_1 = le.transform(X)
# X_train1 = le.transform(X_train)
# X_test1 = le.transform(X_test)

# Preprocessing
pipeline = [
  # ('label_enc', le),
  ('one_hot_enc', onehotenc),
  #  ('scale', scaler),
  #  ('feature_selection', selector)
]
pipeline_preprocess = Pipeline(pipeline)
pipeline_preprocess.fit(X_1, Y)

# Get colname of new dataset features
onehotenc = pipeline_preprocess.steps[0][1]
categorical_onehot_idx = onehotenc.enc.feature_indices_
categorical_onehot_nval = onehotenc.enc.n_values_
colname = []
k=0
for i in categorical_onehot_idx[:-1]:
  feat = list_col_cat[k]
  for j in range(categorical_onehot_nval[k]):
    val = categorical_feat_classes[list_idx_cat[k]][j]
    colname.append("{}_{}".format(feat,val))
  k+=1
lcol_num = [x for x in dtype.index.values if not(x in list_col_cat)]
for i in lcol_num:
  colname.append("{}".format(i))

X_1 = pipeline_preprocess.transform(X_1)
# X_train1 = pipeline_preprocess.transform(X_train1)
# X_test1 = pipeline_preprocess.transform(X_test1)
# Out:
# /home/arditto_trianggada3/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /home/arditto_trianggada3/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:392: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)
# /home/arditto_trianggada3/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function feature_indices_ is deprecated; The ``feature_indices_`` attribute was deprecated in version 0.20 and will be removed 0.22.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/arditto_trianggada3/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function n_values_ is deprecated; The ``n_values_`` attribute was deprecated in version 0.20 and will be removed 0.22.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/arditto_trianggada3/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function feature_indices_ is deprecated; The ``feature_indices_`` attribute was deprecated in version 0.20 and will be removed 0.22.
#   warnings.warn(msg, category=DeprecationWarning)
# /home/arditto_trianggada3/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function n_values_ is deprecated; The ``n_values_`` attribute was deprecated in version 0.20 and will be removed 0.22.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
tmp = X.copy()
tmp['tip_amount'] = Y
pp = sns.pairplot(data=tmp, y_vars=['tip_amount'], x_vars=list_col[0:5])

# %%
corr = X.corr()
fig = plt.figure(figsize=(50,25))
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(data.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(data.columns)
ax.set_yticklabels(data.columns)

# Set ticks on both sides of axes on
ax.tick_params(axis="x", bottom=True, top=True, labelbottom=True, labeltop=True)
# Rotate and align bottom ticklabels
plt.setp([tick.label1 for tick in ax.xaxis.get_major_ticks()], rotation=45,
         ha="right", va="center", rotation_mode="anchor")
# Rotate and align top ticklabels
plt.setp([tick.label2 for tick in ax.xaxis.get_major_ticks()], rotation=45,
         ha="left", va="center",rotation_mode="anchor")

# ax.set_xticklabels(ax.get_xticklabels(),rotation=60)
# ax.set_yticklabels(ax.get_yticklabels(),rotation=60)

mng = plt.get_current_fig_manager()
mng.full_screen_toggle()

plt.show()
# plt.savefig('filename.png')

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_1, Y, test_size=0.3, random_state=100)
# X_train.reset_index(drop=True, inplace=True)
# X_test.reset_index(drop=True, inplace=True)
Y_train.reset_index(drop=True, inplace=True)
Y_test.reset_index(drop=True, inplace=True)

# %%
### Resampling unbalanced dataset
# (1) Over-sampling with SMOTE
# def_ratio = 0.09
# sm = SMOTE(random_state=42, ratio={0:Y_train.value_counts()[0],1:int(Y_train.value_counts()[0]*(def_ratio/(1-def_ratio)))})
# sm.fit(X_train,Y_train)
# X_train_upsampled, Y_train_upsampled = sm.sample(X_train, Y_train)

X_train_upsampled = X_train
Y_train_upsampled = Y_train

# %%
dtrain = xgb.DMatrix(X_train_upsampled, label=Y_train_upsampled)
dtest  = xgb.DMatrix(X_test , label=Y_test )
# Out:
# /home/arditto_trianggada3/anaconda3/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \

# %%
K = 4
kf = KFold(n_splits = K, random_state = 3228, shuffle = True)

# %%
xgb_preds = []
bst = bst_models(colname=colname,score_method="mean")

# %%
def r2_metric(preds, dtrain):
    labels = dtrain.get_label()
    r2 = 1 - (sum((labels-preds )**2)/sum((labels-np.mean(labels))**2))
    return 'r2',r2

# %%
for train_index, test_index in kf.split(X_train_upsampled):
    train = X_train_upsampled; target_train = Y_train_upsampled
    train_X, valid_X = train[train_index], train[test_index]
    train_y, valid_y = target_train[train_index], target_train[test_index]
    
    # Create logistic regression object
    d_train = xgb.DMatrix(train_X, label=train_y,feature_names=colname)
    d_valid = xgb.DMatrix(valid_X, label=valid_y,feature_names=colname)

    xgb_params = {
        'eta': 0.03,
        'max_depth': 4,
        'subsample': 0.75,
        'objective': 'reg:linear',
        'silent': 1,
        'colsample_bytree': 0.8,
        'eval_metric': ['rmse']
    }
    early_stopping = 80
    num_round = 400
    evallist  = [(d_train,'train'), (d_valid,'eval')]
    
    model = xgb.train(
      xgb_params, 
      d_train, 
      num_round,
      evallist,
      feval=r2_metric,
      early_stopping_rounds=early_stopping
    )
    bst.add_model(model)
# Out:
# [0]	train-rmse:2.20847	eval-rmse:2.19989	train-r2:-0.139215	eval-r2:-0.140091
# Multiple eval metrics have been passed: 'eval-r2' will be used for early stopping.
#
# Will train until eval-r2 hasn't improved in 80 rounds.
# [1]	train-rmse:2.18499	eval-rmse:2.17652	train-r2:-0.115178	eval-r2:-0.115945
# [2]	train-rmse:2.16277	eval-rmse:2.15435	train-r2:-0.092571	eval-r2:-0.093358
# [3]	train-rmse:2.14197	eval-rmse:2.13345	train-r2:-0.071559	eval-r2:-0.072227
# [4]	train-rmse:2.12202	eval-rmse:2.11358	train-r2:-0.051765	eval-r2:-0.052346
# [5]	train-rmse:2.10293	eval-rmse:2.09446	train-r2:-0.032859	eval-r2:-0.03335
# [6]	train-rmse:2.0848	eval-rmse:2.07622	train-r2:-0.015029	eval-r2:-0.015479
# [7]	train-rmse:2.06758	eval-rmse:2.05921	train-r2:0.001593	eval-r2:0.001126
# [8]	train-rmse:2.05128	eval-rmse:2.04306	train-r2:0.017214	eval-r2:0.016742
# [9]	train-rmse:2.03585	eval-rmse:2.02756	train-r2:0.031912	eval-r2:0.031556
# [10]	train-rmse:2.02092	eval-rmse:2.01258	train-r2:0.046073	eval-r2:0.045823
# [11]	train-rmse:2.00681	eval-rmse:1.99846	train-r2:0.059329	eval-r2:0.059184
# [12]	train-rmse:1.99323	eval-rmse:1.98491	train-r2:0.072019	eval-r2:0.071873
# [13]	train-rmse:1.9803	eval-rmse:1.97212	train-r2:0.084003	eval-r2:0.083827
# [14]	train-rmse:1.96802	eval-rmse:1.95982	train-r2:0.09536	eval-r2:0.095214
# [15]	train-rmse:1.95644	eval-rmse:1.9482	train-r2:0.105939	eval-r2:0.105899
# [16]	train-rmse:1.94578	eval-rmse:1.93757	train-r2:0.115616	eval-r2:0.11564
# [17]	train-rmse:1.93569	eval-rmse:1.92735	train-r2:0.124899	eval-r2:0.124922
# [18]	train-rmse:1.92572	eval-rmse:1.91727	train-r2:0.133914	eval-r2:0.134044
# [19]	train-rmse:1.9167	eval-rmse:1.90834	train-r2:0.141957	eval-r2:0.14211
# [20]	train-rmse:1.90776	eval-rmse:1.89943	train-r2:0.149958	eval-r2:0.150099
# [21]	train-rmse:1.89906	eval-rmse:1.89082	train-r2:0.157695	eval-r2:0.157765
# [22]	train-rmse:1.89124	eval-rmse:1.88294	train-r2:0.16463	eval-r2:0.164795
# [23]	train-rmse:1.8835	eval-rmse:1.8752	train-r2:0.171446	eval-r2:0.17164
# [24]	train-rmse:1.87632	eval-rmse:1.86813	train-r2:0.177763	eval-r2:0.177885
# [25]	train-rmse:1.86952	eval-rmse:1.86118	train-r2:0.1837	eval-r2:0.183992
# [26]	train-rmse:1.86291	eval-rmse:1.85471	train-r2:0.189447	eval-r2:0.18965
# [27]	train-rmse:1.85659	eval-rmse:1.84849	train-r2:0.194912	eval-r2:0.195091
# [28]	train-rmse:1.85069	eval-rmse:1.8426	train-r2:0.200035	eval-r2:0.200196
# [29]	train-rmse:1.84516	eval-rmse:1.83693	train-r2:0.204805	eval-r2:0.205108
# [30]	train-rmse:1.83982	eval-rmse:1.83165	train-r2:0.209392	eval-r2:0.20967
# [31]	train-rmse:1.83485	eval-rmse:1.82672	train-r2:0.213639	eval-r2:0.213923
# [32]	train-rmse:1.83004	eval-rmse:1.82185	train-r2:0.217782	eval-r2:0.218102
# [33]	train-rmse:1.82546	eval-rmse:1.81729	train-r2:0.221705	eval-r2:0.222022
# [34]	train-rmse:1.82112	eval-rmse:1.81289	train-r2:0.225394	eval-r2:0.225787
# [35]	train-rmse:1.81712	eval-rmse:1.80891	train-r2:0.228805	eval-r2:0.229176
# [36]	train-rmse:1.81319	eval-rmse:1.80499	train-r2:0.232144	eval-r2:0.232511
# [37]	train-rmse:1.80939	eval-rmse:1.80112	train-r2:0.235339	eval-r2:0.235811
# [38]	train-rmse:1.80591	eval-rmse:1.79769	train-r2:0.238276	eval-r2:0.238704
# [39]	train-rmse:1.80267	eval-rmse:1.79439	train-r2:0.241005	eval-r2:0.241506
# [40]	train-rmse:1.7995	eval-rmse:1.79108	train-r2:0.243677	eval-r2:0.244297
# [41]	train-rmse:1.79639	eval-rmse:1.78798	train-r2:0.246283	eval-r2:0.246906
# [42]	train-rmse:1.79361	eval-rmse:1.78515	train-r2:0.248622	eval-r2:0.249293
# [43]	train-rmse:1.79089	eval-rmse:1.78254	train-r2:0.250868	eval-r2:0.251493
# [44]	train-rmse:1.78842	eval-rmse:1.77999	train-r2:0.252933	eval-r2:0.253622
# [45]	train-rmse:1.78594	eval-rmse:1.77748	train-r2:0.255006	eval-r2:0.25573
# [46]	train-rmse:1.78352	eval-rmse:1.7751	train-r2:0.257026	eval-r2:0.25772
# [47]	train-rmse:1.78124	eval-rmse:1.77274	train-r2:0.258934	eval-r2:0.259688
# [48]	train-rmse:1.77909	eval-rmse:1.77055	train-r2:0.260733	eval-r2:0.261525
# [49]	train-rmse:1.77699	eval-rmse:1.76847	train-r2:0.262484	eval-r2:0.263258
# [50]	train-rmse:1.77509	eval-rmse:1.76653	train-r2:0.264041	eval-r2:0.264872
# [51]	train-rmse:1.77314	eval-rmse:1.7646	train-r2:0.265642	eval-r2:0.266482
# [52]	train-rmse:1.77137	eval-rmse:1.76285	train-r2:0.267115	eval-r2:0.267932
# [53]	train-rmse:1.76951	eval-rmse:1.7611	train-r2:0.268648	eval-r2:0.269386
# [54]	train-rmse:1.76788	eval-rmse:1.75941	train-r2:0.269997	eval-r2:0.270786
# [55]	train-rmse:1.76634	eval-rmse:1.75781	train-r2:0.271269	eval-r2:0.272106
# [56]	train-rmse:1.76476	eval-rmse:1.75613	train-r2:0.27259	eval-r2:0.273501
# [57]	train-rmse:1.76338	eval-rmse:1.75468	train-r2:0.273715	eval-r2:0.2747
# [58]	train-rmse:1.76204	eval-rmse:1.75329	train-r2:0.274831	eval-r2:0.275853
# [59]	train-rmse:1.76068	eval-rmse:1.75199	train-r2:0.275932	eval-r2:0.276928
# [60]	train-rmse:1.75936	eval-rmse:1.75068	train-r2:0.277025	eval-r2:0.278007
# [61]	train-rmse:1.75814	eval-rmse:1.74937	train-r2:0.278026	eval-r2:0.279083
# [62]	train-rmse:1.75699	eval-rmse:1.74831	train-r2:0.278975	eval-r2:0.279956
# [63]	train-rmse:1.75594	eval-rmse:1.7473	train-r2:0.279833	eval-r2:0.280789
# [64]	train-rmse:1.75488	eval-rmse:1.74621	train-r2:0.280704	eval-r2:0.281684
# [65]	train-rmse:1.75398	eval-rmse:1.7452	train-r2:0.281451	eval-r2:0.282522
# [66]	train-rmse:1.75298	eval-rmse:1.74409	train-r2:0.282263	eval-r2:0.283431
# [67]	train-rmse:1.75216	eval-rmse:1.74333	train-r2:0.282941	eval-r2:0.284055
# [68]	train-rmse:1.75125	eval-rmse:1.74234	train-r2:0.283681	eval-r2:0.284862
# [69]	train-rmse:1.7504	eval-rmse:1.74144	train-r2:0.284374	eval-r2:0.285608
# [70]	train-rmse:1.74963	eval-rmse:1.74071	train-r2:0.284986	eval-r2:0.286201
# [71]	train-rmse:1.7489	eval-rmse:1.74003	train-r2:0.285593	eval-r2:0.28676
# [72]	train-rmse:1.74817	eval-rmse:1.73936	train-r2:0.286192	eval-r2:0.28731
# [73]	train-rmse:1.74742	eval-rmse:1.73864	train-r2:0.286806	eval-r2:0.287895
# [74]	train-rmse:1.74672	eval-rmse:1.738	train-r2:0.287374	eval-r2:0.28843
# [75]	train-rmse:1.74606	eval-rmse:1.73741	train-r2:0.287914	eval-r2:0.288907
# [76]	train-rmse:1.74548	eval-rmse:1.73681	train-r2:0.288391	eval-r2:0.289397
# [77]	train-rmse:1.74489	eval-rmse:1.73626	train-r2:0.288878	eval-r2:0.289851
# [78]	train-rmse:1.74432	eval-rmse:1.73575	train-r2:0.289342	eval-r2:0.290263
# [79]	train-rmse:1.74366	eval-rmse:1.73517	train-r2:0.289881	eval-r2:0.290742
# [80]	train-rmse:1.74317	eval-rmse:1.73468	train-r2:0.290274	eval-r2:0.29114
# Stopping. Best iteration:
# [0]	train-rmse:2.20847	eval-rmse:2.19989	train-r2:-0.139215	eval-r2:-0.140091
#
# [0]	train-rmse:2.21006	eval-rmse:2.19484	train-r2:-0.139431	eval-r2:-0.139322
# Multiple eval metrics have been passed: 'eval-r2' will be used for early stopping.
#
# Will train until eval-r2 hasn't improved in 80 rounds.
# [1]	train-rmse:2.18671	eval-rmse:2.17137	train-r2:-0.115382	eval-r2:-0.115159
# [2]	train-rmse:2.16419	eval-rmse:2.14893	train-r2:-0.092542	eval-r2:-0.092251
# [3]	train-rmse:2.14315	eval-rmse:2.12801	train-r2:-0.071306	eval-r2:-0.071067
# [4]	train-rmse:2.12335	eval-rmse:2.10845	train-r2:-0.051675	eval-r2:-0.051501
# [5]	train-rmse:2.10393	eval-rmse:2.08928	train-r2:-0.032597	eval-r2:-0.032377
# [6]	train-rmse:2.0858	eval-rmse:2.07094	train-r2:-0.014655	eval-r2:-0.0144
# [7]	train-rmse:2.06847	eval-rmse:2.05395	train-r2:0.002018	eval-r2:0.002217
# [8]	train-rmse:2.05221	eval-rmse:2.03801	train-r2:0.017611	eval-r2:0.01763
# [9]	train-rmse:2.03662	eval-rmse:2.02259	train-r2:0.032435	eval-r2:0.032411
# [10]	train-rmse:2.02151	eval-rmse:2.00757	train-r2:0.046749	eval-r2:0.046746
# [11]	train-rmse:2.00746	eval-rmse:1.99364	train-r2:0.059991	eval-r2:0.059929
# [12]	train-rmse:1.99381	eval-rmse:1.9802	train-r2:0.072731	eval-r2:0.072596
# [13]	train-rmse:1.98088	eval-rmse:1.96751	train-r2:0.084659	eval-r2:0.084421
# [14]	train-rmse:1.96854	eval-rmse:1.95524	train-r2:0.09606	eval-r2:0.095807
# [15]	train-rmse:1.95676	eval-rmse:1.9436	train-r2:0.106837	eval-r2:0.106557
# [16]	train-rmse:1.94597	eval-rmse:1.93284	train-r2:0.11676	eval-r2:0.116398
# [17]	train-rmse:1.93572	eval-rmse:1.92276	train-r2:0.12603	eval-r2:0.125588
# [18]	train-rmse:1.92573	eval-rmse:1.91283	train-r2:0.135027	eval-r2:0.134591
# [19]	train-rmse:1.91676	eval-rmse:1.90396	train-r2:0.143054	eval-r2:0.142606
# [20]	train-rmse:1.90764	eval-rmse:1.89508	train-r2:0.151151	eval-r2:0.150586
# [21]	train-rmse:1.89905	eval-rmse:1.88662	train-r2:0.158817	eval-r2:0.158129
# [22]	train-rmse:1.89109	eval-rmse:1.87885	train-r2:0.165816	eval-r2:0.165068
# [23]	train-rmse:1.88329	eval-rmse:1.87118	train-r2:0.172701	eval-r2:0.171877
# [24]	train-rmse:1.87594	eval-rmse:1.86407	train-r2:0.179155	eval-r2:0.178161
# [25]	train-rmse:1.86898	eval-rmse:1.85735	train-r2:0.185205	eval-r2:0.184073
# [26]	train-rmse:1.86238	eval-rmse:1.85089	train-r2:0.190958	eval-r2:0.189755
# [27]	train-rmse:1.85609	eval-rmse:1.84479	train-r2:0.196423	eval-r2:0.195069
# [28]	train-rmse:1.8501	eval-rmse:1.83891	train-r2:0.201634	eval-r2:0.200205
# [29]	train-rmse:1.84448	eval-rmse:1.83345	train-r2:0.206455	eval-r2:0.204941
# [30]	train-rmse:1.83907	eval-rmse:1.82819	train-r2:0.211099	eval-r2:0.209492
# [31]	train-rmse:1.83414	eval-rmse:1.82346	train-r2:0.215328	eval-r2:0.213578
# [32]	train-rmse:1.82925	eval-rmse:1.81873	train-r2:0.219517	eval-r2:0.21766
# [33]	train-rmse:1.82456	eval-rmse:1.81422	train-r2:0.223512	eval-r2:0.221532
# [34]	train-rmse:1.8202	eval-rmse:1.81009	train-r2:0.227217	eval-r2:0.225075
# [35]	train-rmse:1.81603	eval-rmse:1.80607	train-r2:0.230717	eval-r2:0.228501
# [36]	train-rmse:1.81221	eval-rmse:1.80247	train-r2:0.233975	eval-r2:0.231586
# [37]	train-rmse:1.80846	eval-rmse:1.79895	train-r2:0.23715	eval-r2:0.234578
# [38]	train-rmse:1.80496	eval-rmse:1.79565	train-r2:0.240023	eval-r2:0.237383
# [39]	train-rmse:1.80166	eval-rmse:1.7926	train-r2:0.242795	eval-r2:0.239968
# [40]	train-rmse:1.79823	eval-rmse:1.7892	train-r2:0.245681	eval-r2:0.242855
# [41]	train-rmse:1.7951	eval-rmse:1.78634	train-r2:0.248312	eval-r2:0.245282
# [42]	train-rmse:1.79242	eval-rmse:1.7838	train-r2:0.250577	eval-r2:0.247406
# [43]	train-rmse:1.78982	eval-rmse:1.78134	train-r2:0.252767	eval-r2:0.249491
# [44]	train-rmse:1.78727	eval-rmse:1.77896	train-r2:0.254866	eval-r2:0.251499
# [45]	train-rmse:1.78479	eval-rmse:1.77665	train-r2:0.25695	eval-r2:0.253447
# [46]	train-rmse:1.78238	eval-rmse:1.77436	train-r2:0.258959	eval-r2:0.255347
# [47]	train-rmse:1.77999	eval-rmse:1.77218	train-r2:0.260937	eval-r2:0.257183
# [48]	train-rmse:1.77788	eval-rmse:1.77022	train-r2:0.262707	eval-r2:0.258821
# [49]	train-rmse:1.77568	eval-rmse:1.76819	train-r2:0.264537	eval-r2:0.260531
# [50]	train-rmse:1.77376	eval-rmse:1.76636	train-r2:0.266121	eval-r2:0.262054
# [51]	train-rmse:1.77188	eval-rmse:1.76461	train-r2:0.267691	eval-r2:0.263514
# [52]	train-rmse:1.76993	eval-rmse:1.76281	train-r2:0.269275	eval-r2:0.265019
# [53]	train-rmse:1.76828	eval-rmse:1.76136	train-r2:0.270647	eval-r2:0.26623
# [54]	train-rmse:1.76666	eval-rmse:1.75987	train-r2:0.271976	eval-r2:0.267474
# [55]	train-rmse:1.76516	eval-rmse:1.75849	train-r2:0.273208	eval-r2:0.268623
# [56]	train-rmse:1.76364	eval-rmse:1.75703	train-r2:0.274473	eval-r2:0.269838
# [57]	train-rmse:1.76208	eval-rmse:1.75558	train-r2:0.275752	eval-r2:0.27104
# [58]	train-rmse:1.76061	eval-rmse:1.75423	train-r2:0.276968	eval-r2:0.272156
# [59]	train-rmse:1.75928	eval-rmse:1.75299	train-r2:0.278055	eval-r2:0.273193
# [60]	train-rmse:1.75799	eval-rmse:1.75184	train-r2:0.279093	eval-r2:0.274139
# [61]	train-rmse:1.75676	eval-rmse:1.75076	train-r2:0.2801	eval-r2:0.275034
# [62]	train-rmse:1.75555	eval-rmse:1.7497	train-r2:0.281092	eval-r2:0.275908
# [63]	train-rmse:1.75446	eval-rmse:1.74868	train-r2:0.282	eval-r2:0.276758
# [64]	train-rmse:1.75336	eval-rmse:1.74766	train-r2:0.282905	eval-r2:0.277599
# [65]	train-rmse:1.75239	eval-rmse:1.74688	train-r2:0.28369	eval-r2:0.278241
# [66]	train-rmse:1.75141	eval-rmse:1.74601	train-r2:0.284496	eval-r2:0.278968
# [67]	train-rmse:1.75057	eval-rmse:1.74529	train-r2:0.285177	eval-r2:0.279556
# [68]	train-rmse:1.74968	eval-rmse:1.74449	train-r2:0.285905	eval-r2:0.280222
# [69]	train-rmse:1.74877	eval-rmse:1.74367	train-r2:0.28663	eval-r2:0.280897
# [70]	train-rmse:1.74797	eval-rmse:1.74294	train-r2:0.287292	eval-r2:0.281499
# [71]	train-rmse:1.7472	eval-rmse:1.74227	train-r2:0.287928	eval-r2:0.282045
# [72]	train-rmse:1.74646	eval-rmse:1.74165	train-r2:0.288523	eval-r2:0.282559
# [73]	train-rmse:1.74577	eval-rmse:1.7411	train-r2:0.289078	eval-r2:0.283015
# [74]	train-rmse:1.74497	eval-rmse:1.74045	train-r2:0.289745	eval-r2:0.283549
# [75]	train-rmse:1.74422	eval-rmse:1.73979	train-r2:0.290351	eval-r2:0.284088
# [76]	train-rmse:1.74355	eval-rmse:1.73925	train-r2:0.290899	eval-r2:0.284536
# [77]	train-rmse:1.74288	eval-rmse:1.73862	train-r2:0.291452	eval-r2:0.285059
# [78]	train-rmse:1.74226	eval-rmse:1.7381	train-r2:0.29195	eval-r2:0.285483
# [79]	train-rmse:1.74167	eval-rmse:1.7376	train-r2:0.292432	eval-r2:0.285893
# [80]	train-rmse:1.74104	eval-rmse:1.73719	train-r2:0.292943	eval-r2:0.286236
# Stopping. Best iteration:
# [0]	train-rmse:2.21006	eval-rmse:2.19484	train-r2:-0.139431	eval-r2:-0.139322
#
# [0]	train-rmse:2.20268	eval-rmse:2.21708	train-r2:-0.139308	eval-r2:-0.139769
# Multiple eval metrics have been passed: 'eval-r2' will be used for early stopping.
#
# Will train until eval-r2 hasn't improved in 80 rounds.
# [1]	train-rmse:2.1795	eval-rmse:2.19392	train-r2:-0.115328	eval-r2:-0.116133
# [2]	train-rmse:2.15724	eval-rmse:2.17198	train-r2:-0.092702	eval-r2:-0.093902
# [3]	train-rmse:2.13647	eval-rmse:2.15125	train-r2:-0.071648	eval-r2:-0.073168
# [4]	train-rmse:2.11657	eval-rmse:2.13165	train-r2:-0.051902	eval-r2:-0.053645
# [5]	train-rmse:2.09711	eval-rmse:2.11246	train-r2:-0.032685	eval-r2:-0.034784
# [6]	train-rmse:2.07896	eval-rmse:2.0943	train-r2:-0.014692	eval-r2:-0.017104
# [7]	train-rmse:2.0619	eval-rmse:2.07737	train-r2:0.001827	eval-r2:-0.000708
# [8]	train-rmse:2.04561	eval-rmse:2.06135	train-r2:0.01748	eval-r2:0.014697
# [9]	train-rmse:2.03019	eval-rmse:2.04612	train-r2:0.032224	eval-r2:0.029146
# [10]	train-rmse:2.01512	eval-rmse:2.0313	train-r2:0.046515	eval-r2:0.043164
# [11]	train-rmse:2.00108	eval-rmse:2.01748	train-r2:0.059738	eval-r2:0.05618
# [12]	train-rmse:1.98738	eval-rmse:2.00398	train-r2:0.07254	eval-r2:0.068779
# [13]	train-rmse:1.9746	eval-rmse:1.99135	train-r2:0.084487	eval-r2:0.080483
# [14]	train-rmse:1.9624	eval-rmse:1.97933	train-r2:0.095701	eval-r2:0.091539
# [15]	train-rmse:1.95092	eval-rmse:1.96785	train-r2:0.106397	eval-r2:0.102015
# [16]	train-rmse:1.94011	eval-rmse:1.95709	train-r2:0.116249	eval-r2:0.11182
# [17]	train-rmse:1.92977	eval-rmse:1.94691	train-r2:0.125593	eval-r2:0.121029
# [18]	train-rmse:1.91985	eval-rmse:1.9372	train-r2:0.134603	eval-r2:0.129801
# [19]	train-rmse:1.91067	eval-rmse:1.92826	train-r2:0.142838	eval-r2:0.137813
# [20]	train-rmse:1.90168	eval-rmse:1.91932	train-r2:0.15089	eval-r2:0.145785
# [21]	train-rmse:1.893	eval-rmse:1.91074	train-r2:0.158634	eval-r2:0.1534
# [22]	train-rmse:1.88502	eval-rmse:1.90288	train-r2:0.165719	eval-r2:0.160356
# [23]	train-rmse:1.87725	eval-rmse:1.89532	train-r2:0.17256	eval-r2:0.167007
# [24]	train-rmse:1.86991	eval-rmse:1.888	train-r2:0.179026	eval-r2:0.173447
# [25]	train-rmse:1.86311	eval-rmse:1.88128	train-r2:0.184951	eval-r2:0.179296
# [26]	train-rmse:1.85647	eval-rmse:1.87465	train-r2:0.190775	eval-r2:0.185059
# [27]	train-rmse:1.85019	eval-rmse:1.86856	train-r2:0.196263	eval-r2:0.190367
# [28]	train-rmse:1.84424	eval-rmse:1.8626	train-r2:0.201426	eval-r2:0.195522
# [29]	train-rmse:1.83875	eval-rmse:1.85713	train-r2:0.206178	eval-r2:0.200241
# [30]	train-rmse:1.83335	eval-rmse:1.85186	train-r2:0.210826	eval-r2:0.20477
# [31]	train-rmse:1.82846	eval-rmse:1.84709	train-r2:0.215008	eval-r2:0.208861
# [32]	train-rmse:1.82362	eval-rmse:1.84235	train-r2:0.219189	eval-r2:0.212926
# [33]	train-rmse:1.81899	eval-rmse:1.83772	train-r2:0.223149	eval-r2:0.216864
# [34]	train-rmse:1.81445	eval-rmse:1.83338	train-r2:0.226946	eval-r2:0.220569
# [35]	train-rmse:1.81038	eval-rmse:1.82931	train-r2:0.230479	eval-r2:0.224015
# [36]	train-rmse:1.80643	eval-rmse:1.82548	train-r2:0.233834	eval-r2:0.227267
# [37]	train-rmse:1.80263	eval-rmse:1.82175	train-r2:0.237	eval-r2:0.230429
# [38]	train-rmse:1.79913	eval-rmse:1.81822	train-r2:0.239975	eval-r2:0.233399
# [39]	train-rmse:1.79585	eval-rmse:1.81489	train-r2:0.242744	eval-r2:0.236201
# [40]	train-rmse:1.79256	eval-rmse:1.81165	train-r2:0.245494	eval-r2:0.238929
# [41]	train-rmse:1.7895	eval-rmse:1.80867	train-r2:0.248072	eval-r2:0.241434
# [42]	train-rmse:1.78671	eval-rmse:1.80588	train-r2:0.250434	eval-r2:0.243775
# [43]	train-rmse:1.78408	eval-rmse:1.80338	train-r2:0.252653	eval-r2:0.245865
# [44]	train-rmse:1.78159	eval-rmse:1.80086	train-r2:0.254735	eval-r2:0.247972
# [45]	train-rmse:1.7791	eval-rmse:1.79842	train-r2:0.256805	eval-r2:0.25
# [46]	train-rmse:1.77657	eval-rmse:1.79584	train-r2:0.258943	eval-r2:0.252148
# [47]	train-rmse:1.7742	eval-rmse:1.79354	train-r2:0.260886	eval-r2:0.254074
# [48]	train-rmse:1.77202	eval-rmse:1.79141	train-r2:0.262701	eval-r2:0.255835
# [49]	train-rmse:1.76991	eval-rmse:1.78934	train-r2:0.264457	eval-r2:0.257553
# [50]	train-rmse:1.76803	eval-rmse:1.78746	train-r2:0.266024	eval-r2:0.259115
# [51]	train-rmse:1.76619	eval-rmse:1.78562	train-r2:0.26755	eval-r2:0.260644
# [52]	train-rmse:1.76443	eval-rmse:1.78387	train-r2:0.269013	eval-r2:0.262088
# [53]	train-rmse:1.76264	eval-rmse:1.78207	train-r2:0.270502	eval-r2:0.263575
# [54]	train-rmse:1.76098	eval-rmse:1.78041	train-r2:0.271867	eval-r2:0.264953
# [55]	train-rmse:1.75947	eval-rmse:1.77892	train-r2:0.273117	eval-r2:0.266187
# [56]	train-rmse:1.75792	eval-rmse:1.77736	train-r2:0.274388	eval-r2:0.267468
# [57]	train-rmse:1.75637	eval-rmse:1.77587	train-r2:0.275667	eval-r2:0.26869
# [58]	train-rmse:1.75496	eval-rmse:1.77454	train-r2:0.276839	eval-r2:0.269786
# [59]	train-rmse:1.7537	eval-rmse:1.7734	train-r2:0.27788	eval-r2:0.270728
# [60]	train-rmse:1.75234	eval-rmse:1.77207	train-r2:0.278991	eval-r2:0.271821
# [61]	train-rmse:1.75109	eval-rmse:1.77082	train-r2:0.280021	eval-r2:0.272848
# [62]	train-rmse:1.74992	eval-rmse:1.76963	train-r2:0.280987	eval-r2:0.273826
# [63]	train-rmse:1.74881	eval-rmse:1.76865	train-r2:0.281899	eval-r2:0.274628
# [64]	train-rmse:1.7477	eval-rmse:1.76751	train-r2:0.282811	eval-r2:0.275562
# [65]	train-rmse:1.74679	eval-rmse:1.76661	train-r2:0.283558	eval-r2:0.276303
# [66]	train-rmse:1.74575	eval-rmse:1.76558	train-r2:0.284402	eval-r2:0.277145
# [67]	train-rmse:1.74491	eval-rmse:1.76472	train-r2:0.285101	eval-r2:0.27785
# [68]	train-rmse:1.74397	eval-rmse:1.76381	train-r2:0.285868	eval-r2:0.278594
# [69]	train-rmse:1.74314	eval-rmse:1.76304	train-r2:0.286546	eval-r2:0.279219
# [70]	train-rmse:1.74237	eval-rmse:1.76237	train-r2:0.287171	eval-r2:0.279772
# [71]	train-rmse:1.74164	eval-rmse:1.76176	train-r2:0.287771	eval-r2:0.280268
# [72]	train-rmse:1.7409	eval-rmse:1.76101	train-r2:0.288376	eval-r2:0.280878
# [73]	train-rmse:1.74013	eval-rmse:1.76031	train-r2:0.289001	eval-r2:0.281452
# [74]	train-rmse:1.73938	eval-rmse:1.75962	train-r2:0.289621	eval-r2:0.282022
# [75]	train-rmse:1.73875	eval-rmse:1.75899	train-r2:0.290137	eval-r2:0.28253
# [76]	train-rmse:1.73817	eval-rmse:1.75842	train-r2:0.290611	eval-r2:0.282998
# [77]	train-rmse:1.73758	eval-rmse:1.75782	train-r2:0.291099	eval-r2:0.283482
# [78]	train-rmse:1.73699	eval-rmse:1.75735	train-r2:0.291574	eval-r2:0.283863
# [79]	train-rmse:1.73631	eval-rmse:1.75667	train-r2:0.292132	eval-r2:0.284417
# [80]	train-rmse:1.73581	eval-rmse:1.75623	train-r2:0.292538	eval-r2:0.284782
# Stopping. Best iteration:
# [0]	train-rmse:2.20268	eval-rmse:2.21708	train-r2:-0.139308	eval-r2:-0.139769
#
# [0]	train-rmse:2.20381	eval-rmse:2.2138	train-r2:-0.139648	eval-r2:-0.138801
# Multiple eval metrics have been passed: 'eval-r2' will be used for early stopping.
#
# Will train until eval-r2 hasn't improved in 80 rounds.
# [1]	train-rmse:2.18039	eval-rmse:2.19065	train-r2:-0.115621	eval-r2:-0.115058
# [2]	train-rmse:2.15802	eval-rmse:2.16832	train-r2:-0.092751	eval-r2:-0.092454
# [3]	train-rmse:2.13716	eval-rmse:2.14774	train-r2:-0.071739	eval-r2:-0.071808
# [4]	train-rmse:2.11736	eval-rmse:2.12817	train-r2:-0.051938	eval-r2:-0.052376
# [5]	train-rmse:2.09791	eval-rmse:2.10897	train-r2:-0.032756	eval-r2:-0.033456
# [6]	train-rmse:2.07961	eval-rmse:2.09055	train-r2:-0.014654	eval-r2:-0.015525
# [7]	train-rmse:2.06253	eval-rmse:2.0737	train-r2:0.001891	eval-r2:0.000834
# [8]	train-rmse:2.04627	eval-rmse:2.05742	train-r2:0.017529	eval-r2:0.016447
# [9]	train-rmse:2.0307	eval-rmse:2.04207	train-r2:0.032362	eval-r2:0.031034
# [10]	train-rmse:2.01565	eval-rmse:2.02712	train-r2:0.046673	eval-r2:0.045164
# [11]	train-rmse:2.00175	eval-rmse:2.01337	train-r2:0.059768	eval-r2:0.058103
# [12]	train-rmse:1.98813	eval-rmse:1.99991	train-r2:0.072503	eval-r2:0.070669
# [13]	train-rmse:1.97514	eval-rmse:1.98709	train-r2:0.084529	eval-r2:0.082551
# [14]	train-rmse:1.9629	eval-rmse:1.97504	train-r2:0.095851	eval-r2:0.09364
# [15]	train-rmse:1.95142	eval-rmse:1.96361	train-r2:0.106547	eval-r2:0.104079
# [16]	train-rmse:1.9406	eval-rmse:1.95297	train-r2:0.11644	eval-r2:0.113767
# [17]	train-rmse:1.93025	eval-rmse:1.94274	train-r2:0.12581	eval-r2:0.12302
# [18]	train-rmse:1.92016	eval-rmse:1.93279	train-r2:0.13492	eval-r2:0.131971
# [19]	train-rmse:1.91103	eval-rmse:1.92382	train-r2:0.14312	eval-r2:0.140027
# [20]	train-rmse:1.902	eval-rmse:1.91499	train-r2:0.151156	eval-r2:0.147889
# [21]	train-rmse:1.89334	eval-rmse:1.90638	train-r2:0.158925	eval-r2:0.155552
# [22]	train-rmse:1.88539	eval-rmse:1.89855	train-r2:0.165923	eval-r2:0.162465
# [23]	train-rmse:1.87763	eval-rmse:1.89094	train-r2:0.172805	eval-r2:0.169179
# [24]	train-rmse:1.87034	eval-rmse:1.88375	train-r2:0.179218	eval-r2:0.17549
# [25]	train-rmse:1.86349	eval-rmse:1.87701	train-r2:0.185219	eval-r2:0.181385
# [26]	train-rmse:1.8568	eval-rmse:1.87048	train-r2:0.191051	eval-r2:0.187081
# [27]	train-rmse:1.85049	eval-rmse:1.86426	train-r2:0.196542	eval-r2:0.192465
# [28]	train-rmse:1.84439	eval-rmse:1.85835	train-r2:0.20182	eval-r2:0.197579
# [29]	train-rmse:1.83883	eval-rmse:1.85283	train-r2:0.206629	eval-r2:0.202327
# [30]	train-rmse:1.83344	eval-rmse:1.84757	train-r2:0.211281	eval-r2:0.206856
# [31]	train-rmse:1.82857	eval-rmse:1.84269	train-r2:0.215471	eval-r2:0.211038
# [32]	train-rmse:1.82367	eval-rmse:1.83797	train-r2:0.219665	eval-r2:0.215075
# [33]	train-rmse:1.81898	eval-rmse:1.83343	train-r2:0.223642	eval-r2:0.218941
# [34]	train-rmse:1.81461	eval-rmse:1.82916	train-r2:0.22737	eval-r2:0.222575
# [35]	train-rmse:1.81041	eval-rmse:1.82507	train-r2:0.230972	eval-r2:0.226055
# [36]	train-rmse:1.80644	eval-rmse:1.8212	train-r2:0.234341	eval-r2:0.229326
# [37]	train-rmse:1.80263	eval-rmse:1.81759	train-r2:0.23751	eval-r2:0.232377
# [38]	train-rmse:1.79919	eval-rmse:1.81419	train-r2:0.24044	eval-r2:0.235252
# [39]	train-rmse:1.79593	eval-rmse:1.81097	train-r2:0.243197	eval-r2:0.237959
# [40]	train-rmse:1.79266	eval-rmse:1.80779	train-r2:0.245937	eval-r2:0.240635
# [41]	train-rmse:1.78961	eval-rmse:1.80486	train-r2:0.248502	eval-r2:0.243093
# [42]	train-rmse:1.78676	eval-rmse:1.80205	train-r2:0.250897	eval-r2:0.245442
# [43]	train-rmse:1.78415	eval-rmse:1.79951	train-r2:0.253089	eval-r2:0.247584
# [44]	train-rmse:1.7816	eval-rmse:1.79709	train-r2:0.255243	eval-r2:0.249602
# [45]	train-rmse:1.77909	eval-rmse:1.79467	train-r2:0.257319	eval-r2:0.251619
# [46]	train-rmse:1.77666	eval-rmse:1.79233	train-r2:0.259371	eval-r2:0.253566
# [47]	train-rmse:1.77433	eval-rmse:1.79018	train-r2:0.2613	eval-r2:0.255357
# [48]	train-rmse:1.77205	eval-rmse:1.78807	train-r2:0.263202	eval-r2:0.257113
# [49]	train-rmse:1.76996	eval-rmse:1.78607	train-r2:0.264944	eval-r2:0.25877
# [50]	train-rmse:1.76809	eval-rmse:1.78425	train-r2:0.266488	eval-r2:0.260281
# [51]	train-rmse:1.76615	eval-rmse:1.78244	train-r2:0.268077	eval-r2:0.261781
# [52]	train-rmse:1.76419	eval-rmse:1.78059	train-r2:0.269706	eval-r2:0.263313
# [53]	train-rmse:1.76232	eval-rmse:1.77884	train-r2:0.271254	eval-r2:0.264767
# [54]	train-rmse:1.76064	eval-rmse:1.77729	train-r2:0.272653	eval-r2:0.266045
# [55]	train-rmse:1.75912	eval-rmse:1.77589	train-r2:0.273908	eval-r2:0.267198
# [56]	train-rmse:1.7576	eval-rmse:1.77446	train-r2:0.275152	eval-r2:0.268378
# [57]	train-rmse:1.7561	eval-rmse:1.77296	train-r2:0.276406	eval-r2:0.269613
# [58]	train-rmse:1.75464	eval-rmse:1.77159	train-r2:0.277602	eval-r2:0.270743
# [59]	train-rmse:1.75327	eval-rmse:1.77031	train-r2:0.278716	eval-r2:0.271796
# [60]	train-rmse:1.75194	eval-rmse:1.76907	train-r2:0.279812	eval-r2:0.272823
# [61]	train-rmse:1.75074	eval-rmse:1.76795	train-r2:0.280801	eval-r2:0.273737
# [62]	train-rmse:1.74951	eval-rmse:1.7668	train-r2:0.281815	eval-r2:0.274676
# [63]	train-rmse:1.74839	eval-rmse:1.76575	train-r2:0.282745	eval-r2:0.27555
# [64]	train-rmse:1.74727	eval-rmse:1.76466	train-r2:0.283654	eval-r2:0.276431
# [65]	train-rmse:1.74627	eval-rmse:1.76372	train-r2:0.284466	eval-r2:0.27721
# [66]	train-rmse:1.74527	eval-rmse:1.7628	train-r2:0.285286	eval-r2:0.277967
# [67]	train-rmse:1.74442	eval-rmse:1.76201	train-r2:0.285986	eval-r2:0.278611
# [68]	train-rmse:1.74347	eval-rmse:1.76112	train-r2:0.286769	eval-r2:0.27934
# [69]	train-rmse:1.74249	eval-rmse:1.76018	train-r2:0.28757	eval-r2:0.280102
# [70]	train-rmse:1.74173	eval-rmse:1.75946	train-r2:0.288191	eval-r2:0.280698
# [71]	train-rmse:1.74088	eval-rmse:1.75873	train-r2:0.288878	eval-r2:0.281296
# [72]	train-rmse:1.7401	eval-rmse:1.75813	train-r2:0.289521	eval-r2:0.28178
# [73]	train-rmse:1.73934	eval-rmse:1.75738	train-r2:0.29014	eval-r2:0.282396
# [74]	train-rmse:1.73859	eval-rmse:1.75673	train-r2:0.290752	eval-r2:0.282931
# [75]	train-rmse:1.73794	eval-rmse:1.7561	train-r2:0.291275	eval-r2:0.283441
# [76]	train-rmse:1.7373	eval-rmse:1.75555	train-r2:0.291802	eval-r2:0.283892
# [77]	train-rmse:1.7367	eval-rmse:1.75503	train-r2:0.292291	eval-r2:0.284316
# [78]	train-rmse:1.73613	eval-rmse:1.7545	train-r2:0.292747	eval-r2:0.28475
# [79]	train-rmse:1.73552	eval-rmse:1.75393	train-r2:0.293254	eval-r2:0.285209
# [80]	train-rmse:1.73501	eval-rmse:1.7535	train-r2:0.293667	eval-r2:0.285565
# Stopping. Best iteration:
# [0]	train-rmse:2.20381	eval-rmse:2.2138	train-r2:-0.139648	eval-r2:-0.138801

# %%
# Predict testing data
y_train_pred = bst.predict(X_train)
y_test_pred = bst.predict(X_test)

# %%
compare = {
  'train': pd.DataFrame({'true':Y_train,'pred':y_train_pred}),
  'test': pd.DataFrame({'true':Y_test,'pred':y_test_pred})
}

# %%
# Model evaluation: KS
test_compare = compare['train']
N = test_compare.shape[0]
listidx = random.sample(test_compare.index.values.tolist(),  N)
disp = test_compare.loc[listidx,:]
sns.distplot(a=disp.loc[:,'pred'], hist=True)

# %%
# Model evaluation: KS
test_compare = compare['train']
N = test_compare.shape[0]
listidx = random.sample(test_compare.index.values.tolist(),  N)
disp = test_compare.loc[listidx,:]
ax = sns.regplot(x="true", y="pred", data=disp)

# %%
# Model evaluation: KS
test_compare = compare['test']
N = test_compare.shape[0]
listidx = random.sample(test_compare.index.values.tolist(),  N)
disp = test_compare.loc[listidx,:]
sns.distplot(a=disp.loc[:,'pred'], hist=True)

# %%
# Model evaluation: KS
test_compare = compare['test']
N = test_compare.shape[0]
listidx = random.sample(test_compare.index.values.tolist(),  N)
disp = test_compare.loc[listidx,:]
ax = sns.regplot(x="true", y="pred", data=disp)

# %%
df.tip_amount.describe()
# Out:
# count    1000000.000000
# mean           1.335192
# std            2.055554
# min            0.000000
# 25%            0.000000
# 50%            1.000000
# 75%            2.000000
# max          113.790000
# Name: tip_amount, dtype: float64

# %%
print("RMSE: {}".format(np.sqrt(mean_squared_error(Y_test,y_test_pred))))
print("R2  : {}".format(r2_score(Y_test,y_test_pred)))
# Out:
# RMSE: 1.7120958284103291
# R2  : 0.2877549513521066

# %%
for i,mdl in enumerate(bst.model):
    print("Model:{}".format(i))
    print(pd.Series(mdl.get_fscore()).sort_values(ascending=False))
# Out:
# Model:0
# trip_time_in_secs                                              216
# trip_distance                                                  207
# trip_dist_euclidean                                            150
# rate_code                                                      137
# dropoff_addr_zipcode                                           120
# pickup_addr_zipcode                                             93
# passenger_count                                                 55
# pickup_hour                                                     45
# trip_dist_manhattan                                             33
# is_holiday                                                      25
# dropoff_addr_sublocal_The Bronx                                 24
# dropoff_addr_administrative_area_level_2_Hudson County          15
# dropoff_addr_sublocal_Brooklyn                                  12
# dropoff_addr_administrative_area_level_2_Essex County           10
# dropoff_hour                                                    10
# pickup_addr_administrative_area_level_2_Essex County             9
# pickup_addr_administrative_area_level_2_New York County          8
# dropoff_addr_administrative_area_level_2_Bronx County            6
# dropoff_addr_administrative_area_level_2_Kings County            6
# pickup_addr_administrative_area_level_2_Westchester County       5
# dropoff_addr_administrative_area_level_2_New York County         4
# trip_late_night                                                  4
# dropoff_addr_administrative_area_level_2_Westchester County      3
# pickup_addr_administrative_area_level_2_Hudson County            2
# pickup_dayofweek_Saturday                                        2
# dropoff_addr_administrative_area_level_2_Passaic County          1
# dropoff_dayofweek_Friday                                         1
# pickup_addr_sublocal_Manhattan                                   1
# pickup_dayofweek_Wednesday                                       1
# pickup_dayofweek_Tuesday                                         1
# pickup_addr_sublocal_Queens                                      1
# pickup_addr_administrative_area_level_2_Queens County            1
# dropoff_dayofweek_Thursday                                       1
# dropoff_addr_administrative_area_level_2_Bergen County           1
# dropoff_addr_sublocal_Manhattan                                  1
# dtype: int64
# Model:1
# trip_time_in_secs                                              207
# trip_distance                                                  182
# trip_dist_euclidean                                            161
# dropoff_addr_zipcode                                           155
# rate_code                                                      128
# pickup_addr_zipcode                                             77
# passenger_count                                                 57
# pickup_hour                                                     44
# trip_dist_manhattan                                             41
# dropoff_addr_sublocal_The Bronx                                 26
# is_holiday                                                      18
# dropoff_hour                                                    17
# dropoff_addr_sublocal_Brooklyn                                  13
# pickup_addr_administrative_area_level_2_Westchester County      12
# dropoff_addr_administrative_area_level_2_Essex County           12
# pickup_addr_administrative_area_level_2_Essex County            11
# pickup_addr_administrative_area_level_2_New York County          7
# dropoff_addr_administrative_area_level_2_Kings County            5
# dropoff_addr_administrative_area_level_2_Hudson County           5
# trip_night                                                       4
# dropoff_addr_administrative_area_level_2_New York County         3
# dropoff_addr_administrative_area_level_2_Bronx County            3
# pickup_dayofweek_Tuesday                                         2
# dropoff_addr_sublocal_Manhattan                                  1
# dropoff_dayofweek_Tuesday                                        1
# pickup_dayofweek_Thursday                                        1
# pickup_addr_administrative_area_level_2_Hudson County            1
# pickup_dayofweek_Friday                                          1
# dropoff_dayofweek_Saturday                                       1
# dropoff_addr_administrative_area_level_2_Westchester County      1
# pickup_addr_administrative_area_level_2_Bronx County             1
# pickup_addr_sublocal_Queens                                      1
# pickup_dayofweek_Sunday                                          1
# pickup_dayofweek_Saturday                                        1
# dtype: int64
# Model:2
# trip_time_in_secs                                              198
# trip_distance                                                  185
# trip_dist_euclidean                                            174
# dropoff_addr_zipcode                                           144
# rate_code                                                      134
# pickup_addr_zipcode                                             74
# passenger_count                                                 50
# trip_dist_manhattan                                             49
# pickup_hour                                                     40
# dropoff_addr_sublocal_The Bronx                                 28
# dropoff_hour                                                    17
# is_holiday                                                      17
# dropoff_addr_sublocal_Brooklyn                                  14
# pickup_addr_administrative_area_level_2_Essex County            14
# dropoff_addr_administrative_area_level_2_Bergen County           7
# dropoff_addr_administrative_area_level_2_Kings County            7
# dropoff_addr_administrative_area_level_2_Hudson County           7
# dropoff_addr_administrative_area_level_2_New York County         7
# pickup_addr_administrative_area_level_2_New York County          6
# dropoff_addr_administrative_area_level_2_Essex County            6
# dropoff_addr_sublocal_Manhattan                                  4
# pickup_dayofweek_Monday                                          3
# dropoff_addr_administrative_area_level_2_Westchester County      3
# dropoff_dayofweek_Monday                                         2
# pickup_dayofweek_Thursday                                        2
# dropoff_addr_administrative_area_level_2_Bronx County            2
# pickup_addr_sublocal_Manhattan                                   1
# pickup_dayofweek_Wednesday                                       1
# pickup_addr_sublocal_Queens                                      1
# dropoff_dayofweek_Wednesday                                      1
# pickup_dayofweek_Tuesday                                         1
# dropoff_addr_sublocal_Staten Island                              1
# pickup_addr_administrative_area_level_2_Westchester County       1
# dtype: int64
# Model:3
# trip_time_in_secs                                             202
# trip_distance                                                 188
# trip_dist_euclidean                                           168
# rate_code                                                     150
# dropoff_addr_zipcode                                          128
# pickup_addr_zipcode                                            75
# trip_dist_manhattan                                            50
# passenger_count                                                50
# pickup_hour                                                    46
# dropoff_addr_sublocal_The Bronx                                22
# is_holiday                                                     21
# pickup_addr_administrative_area_level_2_Essex County           16
# dropoff_addr_sublocal_Brooklyn                                 12
# dropoff_hour                                                   12
# dropoff_addr_administrative_area_level_2_Essex County          10
# dropoff_addr_administrative_area_level_2_Hudson County          8
# pickup_addr_administrative_area_level_2_New York County         8
# dropoff_addr_administrative_area_level_2_Bronx County           4
# dropoff_addr_administrative_area_level_2_Kings County           4
# pickup_addr_administrative_area_level_2_Westchester County      4
# dropoff_addr_sublocal_Manhattan                                 3
# pickup_dayofweek_Tuesday                                        2
# trip_late_night                                                 2
# pickup_dayofweek_Wednesday                                      2
# dropoff_addr_administrative_area_level_2_New York County        2
# dropoff_addr_administrative_area_level_2_Bergen County          2
# trip_night                                                      2
# pickup_addr_sublocal_Queens                                     2
# pickup_addr_sublocal_The Bronx                                  1
# pickup_addr_administrative_area_level_2_Bronx County            1
# pickup_addr_administrative_area_level_2_Hudson County           1
# dropoff_dayofweek_Saturday                                      1
# dropoff_addr_administrative_area_level_2_Union County           1
# pickup_dayofweek_Monday                                         1
# pickup_dayofweek_Sunday                                         1
# dtype: int64
